# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account.
#
# Extract all files into the directory: `./05_src/data/prices_csv/`
#
# Your folder structure should include the following paths:
#
# + `05_src/data/prices_csv/etfs`
# + `05_src/data/prices_csv/stocks`

# %%
import pandas as pd
import os
import sys
from glob import glob


sys.path.append(os.getenv('SRC_DIR'))

from utils.logger import get_logger
_logs = get_logger(__name__)

# %%
print(sys.path)
print(os.getenv('SRC_DIR'))
print(os.path.exists(os.getenv('SRC_DIR')))
# Out:
# ['/home/labber/miniconda3/envs/dsi_participant/lib/python39.zip', '/home/labber/miniconda3/envs/dsi_participant/lib/python3.9', '/home/labber/miniconda3/envs/dsi_participant/lib/python3.9/lib-dynload', '', '/home/labber/miniconda3/envs/dsi_participant/lib/python3.9/site-packages', None, '../../05_src/', '../../05_src/', '../../05_src/', '../../05_src/']
# ../../05_src/
# True

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to load the historical price data for stocks and ETFs, we could use:

# %%
os.getenv('SRC_DIR')
os.path
glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
# Out:
# ['../../05_src/data/prices_csv/stocks/MAC.csv',
#  '../../05_src/data/prices_csv/stocks/BCEL.csv',
#  '../../05_src/data/prices_csv/stocks/ACNB.csv',
#  '../../05_src/data/prices_csv/stocks/CHDN.csv',
#  '../../05_src/data/prices_csv/stocks/BABA.csv',
#  '../../05_src/data/prices_csv/stocks/WU.csv',
#  '../../05_src/data/prices_csv/stocks/FONR.csv',
#  '../../05_src/data/prices_csv/stocks/UNT.csv',
#  '../../05_src/data/prices_csv/stocks/STXS.csv',
#  '../../05_src/data/prices_csv/stocks/INFY.csv',
#  '../../05_src/data/prices_csv/stocks/AKRO.csv',
#  '../../05_src/data/prices_csv/stocks/BRFS.csv',
#  '../../05_src/data/prices_csv/stocks/GMED.csv',
#  '../../05_src/data/prices_csv/stocks/ASTE.csv',
#  '../../05_src/data/prices_csv/stocks/DO.csv',
#  '../../05_src/data/prices_csv/stocks/NVTA.csv',
#  '../../05_src/data/prices_csv/stocks/YVR.csv',
#  '../../05_src/data/prices_csv/stocks/NMRD.csv',
#  '../../05_src/data/prices_csv/stocks/SDC.csv',
#  '../../05_src/data/prices_csv/stocks/ANGI.csv',
#  '../../05_src/data/prices_csv/stocks/CNXN.csv',
#  '../../05_src/data/prices_csv/stocks/APPF.csv',
#  '../../05_src/data/prices_csv/stocks/CTR.csv',
#  '../../05_src/data/prices_csv/stocks/VCV.csv',
#  '../../05_src/data/prices_csv/stocks/ADXN.csv',
#  '../../05_src/data/prices_csv/stocks/UNH.csv',
#  '../../05_src/data/prices_csv/stocks/GLNG.csv',
#  '../../05_src/data/prices_csv/stocks/ARKR.csv',
#  '../../05_src/data/prices_csv/stocks/FRBA.csv',
#  '../../05_src/data/prices_csv/stocks/CHKP.csv',
#  '../../05_src/data/prices_csv/stocks/POL.csv',
#  '../../05_src/data/prices_csv/stocks/CVA.csv',
#  '../../05_src/data/prices_csv/stocks/GTT.csv',
#  '../../05_src/data/prices_csv/stocks/SAVE.csv',
#  '../../05_src/data/prices_csv/stocks/ARTL.csv',
#  '../../05_src/data/prices_csv/stocks/MNPR.csv',
#  '../../05_src/data/prices_csv/stocks/HIG.csv',
#  '../../05_src/data/prices_csv/stocks/CASH.csv',
#  '../../05_src/data/prices_csv/stocks/TBPH.csv',
#  '../../05_src/data/prices_csv/stocks/CLGX.csv',
#  '../../05_src/data/prices_csv/stocks/WSC.csv',
#  '../../05_src/data/prices_csv/stocks/SBAC.csv',
#  '../../05_src/data/prices_csv/stocks/CLRB.csv',
#  '../../05_src/data/prices_csv/stocks/FBK.csv',
#  '../../05_src/data/prices_csv/stocks/AMEH.csv',
#  '../../05_src/data/prices_csv/stocks/FOE.csv',
#  '../../05_src/data/prices_csv/stocks/TA.csv',
#  '../../05_src/data/prices_csv/stocks/NTRS.csv',
#  '../../05_src/data/prices_csv/stocks/FFBC.csv',
#  '../../05_src/data/prices_csv/stocks/RBC.csv',
#  '../../05_src/data/prices_csv/stocks/SUMR.csv',
#  '../../05_src/data/prices_csv/stocks/LNDC.csv',
#  '../../05_src/data/prices_csv/stocks/VIAV.csv',
#  '../../05_src/data/prices_csv/stocks/ERII.csv',
#  '../../05_src/data/prices_csv/stocks/WBS.csv',
#  '../../05_src/data/prices_csv/stocks/VRT.csv',
#  '../../05_src/data/prices_csv/stocks/PANW.csv',
#  '../../05_src/data/prices_csv/stocks/EH.csv',
#  '../../05_src/data/prices_csv/stocks/CNS.csv',
#  '../../05_src/data/prices_csv/stocks/EBSB.csv',
#  '../../05_src/data/prices_csv/stocks/SSKN.csv',
#  '../../05_src/data/prices_csv/stocks/SMTX.csv',
#  '../../05_src/data/prices_csv/stocks/TGS.csv',
#  '../../05_src/data/prices_csv/stocks/MUDS.csv',
#  '../../05_src/data/prices_csv/stocks/CPHI.csv',
#  '../../05_src/data/prices_csv/stocks/ATXI.csv',
#  '../../05_src/data/prices_csv/stocks/HSIC.csv',
#  '../../05_src/data/prices_csv/stocks/SBBX.csv',
#  '../../05_src/data/prices_csv/stocks/ALO.csv',
#  '../../05_src/data/prices_csv/stocks/NWN.csv',
#  '../../05_src/data/prices_csv/stocks/BNGO.csv',
#  '../../05_src/data/prices_csv/stocks/REXN.csv',
#  '../../05_src/data/prices_csv/stocks/ALTM.csv',
#  '../../05_src/data/prices_csv/stocks/RADA.csv',
#  '../../05_src/data/prices_csv/stocks/MSFT.csv',
#  '../../05_src/data/prices_csv/stocks/SES.csv',
#  '../../05_src/data/prices_csv/stocks/SRDX.csv',
#  '../../05_src/data/prices_csv/stocks/EOI.csv',
#  '../../05_src/data/prices_csv/stocks/GLYC.csv',
#  '../../05_src/data/prices_csv/stocks/CFG.csv',
#  '../../05_src/data/prices_csv/stocks/TD.csv',
#  '../../05_src/data/prices_csv/stocks/JHG.csv',
#  '../../05_src/data/prices_csv/stocks/BTG.csv',
#  '../../05_src/data/prices_csv/stocks/BSA.csv',
#  '../../05_src/data/prices_csv/stocks/BHB.csv',
#  '../../05_src/data/prices_csv/stocks/ORGS.csv',
#  '../../05_src/data/prices_csv/stocks/BITA.csv',
#  '../../05_src/data/prices_csv/stocks/WLTW.csv',
#  '../../05_src/data/prices_csv/stocks/NIQ.csv',
#  '../../05_src/data/prices_csv/stocks/GRU.csv',
#  '../../05_src/data/prices_csv/stocks/HBM.csv',
#  '../../05_src/data/prices_csv/stocks/ATR.csv',
#  '../../05_src/data/prices_csv/stocks/PD.csv',
#  '../../05_src/data/prices_csv/stocks/SVT.csv',
#  '../../05_src/data/prices_csv/stocks/MCC.csv',
#  '../../05_src/data/prices_csv/stocks/SLVO.csv',
#  '../../05_src/data/prices_csv/stocks/DFVL.csv',
#  '../../05_src/data/prices_csv/stocks/TRX.csv',
#  '../../05_src/data/prices_csv/stocks/SSTI.csv',
#  '../../05_src/data/prices_csv/stocks/ISIG.csv',
#  '../../05_src/data/prices_csv/stocks/EDN.csv',
#  '../../05_src/data/prices_csv/stocks/MCO.csv',
#  '../../05_src/data/prices_csv/stocks/EOLS.csv',
#  '../../05_src/data/prices_csv/stocks/ISSC.csv',
#  '../../05_src/data/prices_csv/stocks/CNET.csv',
#  '../../05_src/data/prices_csv/stocks/DCP.csv',
#  '../../05_src/data/prices_csv/stocks/EZPW.csv',
#  '../../05_src/data/prices_csv/stocks/PDFS.csv',
#  '../../05_src/data/prices_csv/stocks/FIX.csv',
#  '../../05_src/data/prices_csv/stocks/KRUS.csv',
#  '../../05_src/data/prices_csv/stocks/IRIX.csv',
#  '../../05_src/data/prices_csv/stocks/ASH.csv',
#  '../../05_src/data/prices_csv/stocks/AFC.csv',
#  '../../05_src/data/prices_csv/stocks/THGA.csv',
#  '../../05_src/data/prices_csv/stocks/RDWR.csv',
#  '../../05_src/data/prices_csv/stocks/PLXP.csv',
#  '../../05_src/data/prices_csv/stocks/WSBC.csv',
#  '../../05_src/data/prices_csv/stocks/MYFW.csv',
#  '../../05_src/data/prices_csv/stocks/IMAC.csv',
#  '../../05_src/data/prices_csv/stocks/OTEX.csv',
#  '../../05_src/data/prices_csv/stocks/BG.csv',
#  '../../05_src/data/prices_csv/stocks/BKN.csv',
#  '../../05_src/data/prices_csv/stocks/CYBR.csv',
#  '../../05_src/data/prices_csv/stocks/MEDP.csv',
#  '../../05_src/data/prices_csv/stocks/FNHC.csv',
#  '../../05_src/data/prices_csv/stocks/RDNT.csv',
#  '../../05_src/data/prices_csv/stocks/TCP.csv',
#  '../../05_src/data/prices_csv/stocks/INNT.csv',
#  '../../05_src/data/prices_csv/stocks/DAC.csv',
#  '../../05_src/data/prices_csv/stocks/SENEB.csv',
#  '../../05_src/data/prices_csv/stocks/LOV.csv',
#  '../../05_src/data/prices_csv/stocks/CET.csv',
#  '../../05_src/data/prices_csv/stocks/PEGA.csv',
#  '../../05_src/data/prices_csv/stocks/WHFBZ.csv',
#  '../../05_src/data/prices_csv/stocks/THTX.csv',
#  '../../05_src/data/prices_csv/stocks/ESXB.csv',
#  '../../05_src/data/prices_csv/stocks/RILYZ.csv',
#  '../../05_src/data/prices_csv/stocks/OPHC.csv',
#  '../../05_src/data/prices_csv/stocks/MRCC.csv',
#  '../../05_src/data/prices_csv/stocks/STL.csv',
#  '../../05_src/data/prices_csv/stocks/CDTX.csv',
#  '../../05_src/data/prices_csv/stocks/AMH.csv',
#  '../../05_src/data/prices_csv/stocks/XIN.csv',
#  '../../05_src/data/prices_csv/stocks/EDSA.csv',
#  '../../05_src/data/prices_csv/stocks/DSPG.csv',
#  '../../05_src/data/prices_csv/stocks/NVST.csv',
#  '../../05_src/data/prices_csv/stocks/NTIP.csv',
#  '../../05_src/data/prices_csv/stocks/FSBC.csv',
#  '../../05_src/data/prices_csv/stocks/BHFAP.csv',
#  '../../05_src/data/prices_csv/stocks/GWPH.csv',
#  '../../05_src/data/prices_csv/stocks/HROW.csv',
#  '../../05_src/data/prices_csv/stocks/BPMP.csv',
#  '../../05_src/data/prices_csv/stocks/EOT.csv',
#  '../../05_src/data/prices_csv/stocks/CYRX.csv',
#  '../../05_src/data/prices_csv/stocks/CBH.csv',
#  '../../05_src/data/prices_csv/stocks/SKYS.csv',
#  '../../05_src/data/prices_csv/stocks/OKE.csv',
#  '../../05_src/data/prices_csv/stocks/USV.csv',
#  '../../05_src/data/prices_csv/stocks/DTSS.csv',
#  '../../05_src/data/prices_csv/stocks/PTE.csv',
#  '../../05_src/data/prices_csv/stocks/TCFC.csv',
#  '../../05_src/data/prices_csv/stocks/AZRX.csv',
#  '../../05_src/data/prices_csv/stocks/JRSH.csv',
#  '../../05_src/data/prices_csv/stocks/FLIC.csv',
#  '../../05_src/data/prices_csv/stocks/REVG.csv',
#  '../../05_src/data/prices_csv/stocks/LEGH.csv',
#  '../../05_src/data/prices_csv/stocks/LONE.csv',
#  '../../05_src/data/prices_csv/stocks/WKEY.csv',
#  '../../05_src/data/prices_csv/stocks/MGNX.csv',
#  '../../05_src/data/prices_csv/stocks/RILYO.csv',
#  '../../05_src/data/prices_csv/stocks/ATEC.csv',
#  '../../05_src/data/prices_csv/stocks/XLNX.csv',
#  '../../05_src/data/prices_csv/stocks/JHX.csv',
#  '../../05_src/data/prices_csv/stocks/BC.csv',
#  '../../05_src/data/prices_csv/stocks/ETNB.csv',
#  '../../05_src/data/prices_csv/stocks/CVEO.csv',
#  '../../05_src/data/prices_csv/stocks/GRX.csv',
#  '../../05_src/data/prices_csv/stocks/OPGN.csv',
#  '../../05_src/data/prices_csv/stocks/LOOP.csv',
#  '../../05_src/data/prices_csv/stocks/PSEC.csv',
#  '../../05_src/data/prices_csv/stocks/BSD.csv',
#  '../../05_src/data/prices_csv/stocks/MXE.csv',
#  '../../05_src/data/prices_csv/stocks/NTLA.csv',
#  '../../05_src/data/prices_csv/stocks/CENX.csv',
#  '../../05_src/data/prices_csv/stocks/PINC.csv',
#  '../../05_src/data/prices_csv/stocks/HOFT.csv',
#  '../../05_src/data/prices_csv/stocks/FRT.csv',
#  '../../05_src/data/prices_csv/stocks/JBHT.csv',
#  '../../05_src/data/prices_csv/stocks/MRCY.csv',
#  '../../05_src/data/prices_csv/stocks/BW.csv',
#  '../../05_src/data/prices_csv/stocks/HUBB.csv',
#  '../../05_src/data/prices_csv/stocks/TREX.csv',
#  '../../05_src/data/prices_csv/stocks/EFL.csv',
#  '../../05_src/data/prices_csv/stocks/CABO.csv',
#  '../../05_src/data/prices_csv/stocks/TXT.csv',
#  '../../05_src/data/prices_csv/stocks/EE.csv',
#  '../../05_src/data/prices_csv/stocks/MBWM.csv',
#  '../../05_src/data/prices_csv/stocks/GRWG.csv',
#  '../../05_src/data/prices_csv/stocks/TZAC.csv',
#  '../../05_src/data/prices_csv/stocks/SFET.csv',
#  '../../05_src/data/prices_csv/stocks/APDN.csv',
#  '../../05_src/data/prices_csv/stocks/HYRE.csv',
#  '../../05_src/data/prices_csv/stocks/DLY.csv',
#  '../../05_src/data/prices_csv/stocks/PDEX.csv',
#  '../../05_src/data/prices_csv/stocks/BTU.csv',
#  '../../05_src/data/prices_csv/stocks/TSRI.csv',
#  '../../05_src/data/prices_csv/stocks/EXPR.csv',
#  '../../05_src/data/prices_csv/stocks/DLNG.csv',
#  '../../05_src/data/prices_csv/stocks/PER.csv',
#  '../../05_src/data/prices_csv/stocks/MVC.csv',
#  '../../05_src/data/prices_csv/stocks/PYPL.csv',
#  '../../05_src/data/prices_csv/stocks/EXPE.csv',
#  '../../05_src/data/prices_csv/stocks/KREF.csv',
#  '../../05_src/data/prices_csv/stocks/NCZ.csv',
#  '../../05_src/data/prices_csv/stocks/BKR.csv',
#  '../../05_src/data/prices_csv/stocks/SOHOO.csv',
#  '../../05_src/data/prices_csv/stocks/TREC.csv',
#  '../../05_src/data/prices_csv/stocks/WTREP.csv',
#  '../../05_src/data/prices_csv/stocks/WEYS.csv',
#  '../../05_src/data/prices_csv/stocks/LMAT.csv',
#  '../../05_src/data/prices_csv/stocks/RARX.csv',
#  '../../05_src/data/prices_csv/stocks/UVV.csv',
#  '../../05_src/data/prices_csv/stocks/ADBE.csv',
#  '../../05_src/data/prices_csv/stocks/QCRH.csv',
#  '../../05_src/data/prices_csv/stocks/ECOL.csv',
#  '../../05_src/data/prices_csv/stocks/TRCH.csv',
#  '../../05_src/data/prices_csv/stocks/CVV.csv',
#  '../../05_src/data/prices_csv/stocks/RUHN.csv',
#  '../../05_src/data/prices_csv/stocks/FSFG.csv',
#  '../../05_src/data/prices_csv/stocks/FRHC.csv',
#  '../../05_src/data/prices_csv/stocks/RNGR.csv',
#  '../../05_src/data/prices_csv/stocks/ERJ.csv',
#  '../../05_src/data/prices_csv/stocks/SHOP.csv',
#  '../../05_src/data/prices_csv/stocks/NFH.csv',
#  '../../05_src/data/prices_csv/stocks/SM.csv',
#  '../../05_src/data/prices_csv/stocks/NURO.csv',
#  '../../05_src/data/prices_csv/stocks/SSY.csv',
#  '../../05_src/data/prices_csv/stocks/VALE.csv',
#  '../../05_src/data/prices_csv/stocks/HXL.csv',
#  '../../05_src/data/prices_csv/stocks/MBUU.csv',
#  '../../05_src/data/prices_csv/stocks/FSV.csv',
#  '../../05_src/data/prices_csv/stocks/MPX.csv',
#  '../../05_src/data/prices_csv/stocks/KSU.csv',
#  '../../05_src/data/prices_csv/stocks/PFS.csv',
#  '../../05_src/data/prices_csv/stocks/PPIH.csv',
#  '../../05_src/data/prices_csv/stocks/EIM.csv',
#  '../../05_src/data/prices_csv/stocks/DZSI.csv',
#  '../../05_src/data/prices_csv/stocks/IDEX.csv',
#  '../../05_src/data/prices_csv/stocks/ACY.csv',
#  '../../05_src/data/prices_csv/stocks/NESR.csv',
#  '../../05_src/data/prices_csv/stocks/PGP.csv',
#  '../../05_src/data/prices_csv/stocks/GEF.csv',
#  '../../05_src/data/prices_csv/stocks/RMM.csv',
#  '../../05_src/data/prices_csv/stocks/EPIX.csv',
#  '../../05_src/data/prices_csv/stocks/BSET.csv',
#  '../../05_src/data/prices_csv/stocks/VGI.csv',
#  '../../05_src/data/prices_csv/stocks/CSTM.csv',
#  '../../05_src/data/prices_csv/stocks/BLRX.csv',
#  '../../05_src/data/prices_csv/stocks/ESTE.csv',
#  '../../05_src/data/prices_csv/stocks/ARNA.csv',
#  '../../05_src/data/prices_csv/stocks/CO.csv',
#  '../../05_src/data/prices_csv/stocks/CLM.csv',
#  '../../05_src/data/prices_csv/stocks/ANIK.csv',
#  '../../05_src/data/prices_csv/stocks/XXII.csv',
#  '../../05_src/data/prices_csv/stocks/UBSI.csv',
#  '../../05_src/data/prices_csv/stocks/ANET.csv',
#  '../../05_src/data/prices_csv/stocks/FFIC.csv',
#  '../../05_src/data/prices_csv/stocks/MSBF.csv',
#  '../../05_src/data/prices_csv/stocks/MMD.csv',
#  '../../05_src/data/prices_csv/stocks/VTR.csv',
#  '../../05_src/data/prices_csv/stocks/IAG.csv',
#  '../../05_src/data/prices_csv/stocks/SSRM.csv',
#  '../../05_src/data/prices_csv/stocks/EXPO.csv',
#  '../../05_src/data/prices_csv/stocks/SEE.csv',
#  '../../05_src/data/prices_csv/stocks/MCX.csv',
#  '../../05_src/data/prices_csv/stocks/MDCA.csv',
#  '../../05_src/data/prices_csv/stocks/REZI.csv',
#  '../../05_src/data/prices_csv/stocks/KRC.csv',
#  '../../05_src/data/prices_csv/stocks/DFIN.csv',
#  '../../05_src/data/prices_csv/stocks/BTE.csv',
#  '../../05_src/data/prices_csv/stocks/LNTH.csv',
#  '../../05_src/data/prices_csv/stocks/GIFI.csv',
#  '../../05_src/data/prices_csv/stocks/XLRN.csv',
#  '../../05_src/data/prices_csv/stocks/TTI.csv',
#  '../../05_src/data/prices_csv/stocks/DRADP.csv',
#  '../../05_src/data/prices_csv/stocks/GMLP.csv',
#  '../../05_src/data/prices_csv/stocks/SCPH.csv',
#  '../../05_src/data/prices_csv/stocks/ICLR.csv',
#  '../../05_src/data/prices_csv/stocks/PML.csv',
#  '../../05_src/data/prices_csv/stocks/ICAD.csv',
#  '../../05_src/data/prices_csv/stocks/GILT.csv',
#  '../../05_src/data/prices_csv/stocks/XOG.csv',
#  '../../05_src/data/prices_csv/stocks/GCV.csv',
#  '../../05_src/data/prices_csv/stocks/BPMX.csv',
#  '../../05_src/data/prices_csv/stocks/FSLR.csv',
#  '../../05_src/data/prices_csv/stocks/RBS.csv',
#  '../../05_src/data/prices_csv/stocks/TARA.csv',
#  '../../05_src/data/prices_csv/stocks/GSHD.csv',
#  '../../05_src/data/prices_csv/stocks/OFSSI.csv',
#  '../../05_src/data/prices_csv/stocks/CMCSA.csv',
#  '../../05_src/data/prices_csv/stocks/CLRO.csv',
#  '../../05_src/data/prices_csv/stocks/BPYUP.csv',
#  '../../05_src/data/prices_csv/stocks/SENS.csv',
#  '../../05_src/data/prices_csv/stocks/CTS.csv',
#  '../../05_src/data/prices_csv/stocks/MHF.csv',
#  '../../05_src/data/prices_csv/stocks/LACQU.csv',
#  '../../05_src/data/prices_csv/stocks/VHC.csv',
#  '../../05_src/data/prices_csv/stocks/AGO.csv',
#  '../../05_src/data/prices_csv/stocks/GTYH.csv',
#  '../../05_src/data/prices_csv/stocks/HLT.csv',
#  '../../05_src/data/prices_csv/stocks/KDMN.csv',
#  '../../05_src/data/prices_csv/stocks/CEMI.csv',
#  '../../05_src/data/prices_csv/stocks/TNET.csv',
#  '../../05_src/data/prices_csv/stocks/SESN.csv',
#  '../../05_src/data/prices_csv/stocks/MIRM.csv',
#  '../../05_src/data/prices_csv/stocks/SWCH.csv',
#  '../../05_src/data/prices_csv/stocks/PEP.csv',
#  '../../05_src/data/prices_csv/stocks/HD.csv',
#  '../../05_src/data/prices_csv/stocks/RZA.csv',
#  '../../05_src/data/prices_csv/stocks/VCTR.csv',
#  '../../05_src/data/prices_csv/stocks/CMRE.csv',
#  '../../05_src/data/prices_csv/stocks/EBF.csv',
#  '../../05_src/data/prices_csv/stocks/SHEN.csv',
#  '../../05_src/data/prices_csv/stocks/ATGE.csv',
#  '../../05_src/data/prices_csv/stocks/AVYA.csv',
#  '../../05_src/data/prices_csv/stocks/PAI.csv',
#  '../../05_src/data/prices_csv/stocks/AMWD.csv',
#  '../../05_src/data/prices_csv/stocks/PFE.csv',
#  '../../05_src/data/prices_csv/stocks/PIHPP.csv',
#  '../../05_src/data/prices_csv/stocks/NVAX.csv',
#  '../../05_src/data/prices_csv/stocks/NGVC.csv',
#  '../../05_src/data/prices_csv/stocks/UPWK.csv',
#  '../../05_src/data/prices_csv/stocks/GPMT.csv',
#  '../../05_src/data/prices_csv/stocks/BBBY.csv',
#  '../../05_src/data/prices_csv/stocks/NXR.csv',
#  '../../05_src/data/prices_csv/stocks/CCMP.csv',
#  '../../05_src/data/prices_csv/stocks/WTFC.csv',
#  '../../05_src/data/prices_csv/stocks/VLYPP.csv',
#  '../../05_src/data/prices_csv/stocks/UCIB.csv',
#  '../../05_src/data/prices_csv/stocks/MYD.csv',
#  '../../05_src/data/prices_csv/stocks/WES.csv',
#  '../../05_src/data/prices_csv/stocks/BHF.csv',
#  '../../05_src/data/prices_csv/stocks/SSP.csv',
#  '../../05_src/data/prices_csv/stocks/AVNW.csv',
#  '../../05_src/data/prices_csv/stocks/ZFGN.csv',
#  '../../05_src/data/prices_csv/stocks/GES.csv',
#  '../../05_src/data/prices_csv/stocks/NTZ.csv',
#  '../../05_src/data/prices_csv/stocks/AWR.csv',
#  '../../05_src/data/prices_csv/stocks/SFTW.csv',
#  '../../05_src/data/prices_csv/stocks/SP.csv',
#  '../../05_src/data/prices_csv/stocks/XENT.csv',
#  '../../05_src/data/prices_csv/stocks/GRVY.csv',
#  '../../05_src/data/prices_csv/stocks/INSE.csv',
#  '../../05_src/data/prices_csv/stocks/REPL.csv',
#  '../../05_src/data/prices_csv/stocks/CDNS.csv',
#  '../../05_src/data/prices_csv/stocks/AGM-A.csv',
#  '../../05_src/data/prices_csv/stocks/AWRE.csv',
#  '../../05_src/data/prices_csv/stocks/ATLC.csv',
#  '../../05_src/data/prices_csv/stocks/SHAK.csv',
#  '../../05_src/data/prices_csv/stocks/MS.csv',
#  '../../05_src/data/prices_csv/stocks/ORSN.csv',
#  '../../05_src/data/prices_csv/stocks/MX.csv',
#  '../../05_src/data/prices_csv/stocks/ALOT.csv',
#  '../../05_src/data/prices_csv/stocks/CDR.csv',
#  '../../05_src/data/prices_csv/stocks/IRMD.csv',
#  '../../05_src/data/prices_csv/stocks/ADSK.csv',
#  '../../05_src/data/prices_csv/stocks/VRTV.csv',
#  '../../05_src/data/prices_csv/stocks/STRT.csv',
#  '../../05_src/data/prices_csv/stocks/MCY.csv',
#  '../../05_src/data/prices_csv/stocks/IBTX.csv',
#  '../../05_src/data/prices_csv/stocks/CMLS.csv',
#  '../../05_src/data/prices_csv/stocks/STAR.csv',
#  '../../05_src/data/prices_csv/stocks/ZTS.csv',
#  '../../05_src/data/prices_csv/stocks/MUJ.csv',
#  '../../05_src/data/prices_csv/stocks/NBY.csv',
#  '../../05_src/data/prices_csv/stocks/GLADD.csv',
#  '../../05_src/data/prices_csv/stocks/VBIV.csv',
#  '../../05_src/data/prices_csv/stocks/PGTI.csv',
#  '../../05_src/data/prices_csv/stocks/DGP.csv',
#  '../../05_src/data/prices_csv/stocks/GJP.csv',
#  '../../05_src/data/prices_csv/stocks/SND.csv',
#  '../../05_src/data/prices_csv/stocks/HWCPL.csv',
#  '../../05_src/data/prices_csv/stocks/FFBW.csv',
#  '../../05_src/data/prices_csv/stocks/BYND.csv',
#  '../../05_src/data/prices_csv/stocks/HURN.csv',
#  '../../05_src/data/prices_csv/stocks/VTNR.csv',
#  '../../05_src/data/prices_csv/stocks/AGM.csv',
#  '../../05_src/data/prices_csv/stocks/URI.csv',
#  '../../05_src/data/prices_csv/stocks/FGEN.csv',
#  '../../05_src/data/prices_csv/stocks/MGI.csv',
#  '../../05_src/data/prices_csv/stocks/SUNS.csv',
#  '../../05_src/data/prices_csv/stocks/AUB.csv',
#  '../../05_src/data/prices_csv/stocks/VECO.csv',
#  '../../05_src/data/prices_csv/stocks/PYX.csv',
#  '../../05_src/data/prices_csv/stocks/QLYS.csv',
#  '../../05_src/data/prices_csv/stocks/KSM.csv',
#  '../../05_src/data/prices_csv/stocks/RSG.csv',
#  '../../05_src/data/prices_csv/stocks/SYPR.csv',
#  '../../05_src/data/prices_csv/stocks/IGMS.csv',
#  '../../05_src/data/prices_csv/stocks/CCK.csv',
#  '../../05_src/data/prices_csv/stocks/AMAL.csv',
#  '../../05_src/data/prices_csv/stocks/HUGE.csv',
#  '../../05_src/data/prices_csv/stocks/PTON.csv',
#  '../../05_src/data/prices_csv/stocks/CHH.csv',
#  '../../05_src/data/prices_csv/stocks/DOV.csv',
#  '../../05_src/data/prices_csv/stocks/RCKT.csv',
#  '../../05_src/data/prices_csv/stocks/JJT.csv',
#  '../../05_src/data/prices_csv/stocks/FLEX.csv',
#  '../../05_src/data/prices_csv/stocks/LBRDA.csv',
#  '../../05_src/data/prices_csv/stocks/GRIL.csv',
#  '../../05_src/data/prices_csv/stocks/WORX.csv',
#  '../../05_src/data/prices_csv/stocks/EVER.csv',
#  '../../05_src/data/prices_csv/stocks/WWW.csv',
#  '../../05_src/data/prices_csv/stocks/CBAY.csv',
#  '../../05_src/data/prices_csv/stocks/LYTS.csv',
#  '../../05_src/data/prices_csv/stocks/NRGU.csv',
#  '../../05_src/data/prices_csv/stocks/PFHD.csv',
#  '../../05_src/data/prices_csv/stocks/CWCO.csv',
#  '../../05_src/data/prices_csv/stocks/FTAC.csv',
#  '../../05_src/data/prices_csv/stocks/BLDR.csv',
#  '../../05_src/data/prices_csv/stocks/WSG.csv',
#  '../../05_src/data/prices_csv/stocks/CLUB.csv',
#  '../../05_src/data/prices_csv/stocks/AVGOP.csv',
#  '../../05_src/data/prices_csv/stocks/KEY.csv',
#  '../../05_src/data/prices_csv/stocks/AXGT.csv',
#  '../../05_src/data/prices_csv/stocks/CMU.csv',
#  '../../05_src/data/prices_csv/stocks/PRNB.csv',
#  '../../05_src/data/prices_csv/stocks/PNTG.csv',
#  '../../05_src/data/prices_csv/stocks/SPKE.csv',
#  '../../05_src/data/prices_csv/stocks/ECOR.csv',
#  '../../05_src/data/prices_csv/stocks/PHK.csv',
#  '../../05_src/data/prices_csv/stocks/DSU.csv',
#  '../../05_src/data/prices_csv/stocks/HSKA.csv',
#  '../../05_src/data/prices_csv/stocks/CNOB.csv',
#  '../../05_src/data/prices_csv/stocks/ATO.csv',
#  '../../05_src/data/prices_csv/stocks/WPC.csv',
#  '../../05_src/data/prices_csv/stocks/TROV.csv',
#  '../../05_src/data/prices_csv/stocks/TS.csv',
#  '../../05_src/data/prices_csv/stocks/NJV.csv',
#  '../../05_src/data/prices_csv/stocks/PING.csv',
#  '../../05_src/data/prices_csv/stocks/EVOK.csv',
#  '../../05_src/data/prices_csv/stocks/BLUE.csv',
#  '../../05_src/data/prices_csv/stocks/CGC.csv',
#  '../../05_src/data/prices_csv/stocks/TILE.csv',
#  '../../05_src/data/prices_csv/stocks/PACB.csv',
#  '../../05_src/data/prices_csv/stocks/SCS.csv',
#  '../../05_src/data/prices_csv/stocks/ARCB.csv',
#  '../../05_src/data/prices_csv/stocks/OIA.csv',
#  '../../05_src/data/prices_csv/stocks/IRM.csv',
#  '../../05_src/data/prices_csv/stocks/INSM.csv',
#  '../../05_src/data/prices_csv/stocks/AXO.csv',
#  '../../05_src/data/prices_csv/stocks/KIDS.csv',
#  '../../05_src/data/prices_csv/stocks/UAUD.csv',
#  '../../05_src/data/prices_csv/stocks/ITUB.csv',
#  '../../05_src/data/prices_csv/stocks/VCRA.csv',
#  '../../05_src/data/prices_csv/stocks/SZC.csv',
#  '../../05_src/data/prices_csv/stocks/NEP.csv',
#  '../../05_src/data/prices_csv/stocks/GMHIU.csv',
#  '../../05_src/data/prices_csv/stocks/TCBIL.csv',
#  '../../05_src/data/prices_csv/stocks/APTX.csv',
#  '../../05_src/data/prices_csv/stocks/TRVN.csv',
#  '../../05_src/data/prices_csv/stocks/BPOPN.csv',
#  '../../05_src/data/prices_csv/stocks/KRA.csv',
#  '../../05_src/data/prices_csv/stocks/APPS.csv',
#  '../../05_src/data/prices_csv/stocks/FCBP.csv',
#  '../../05_src/data/prices_csv/stocks/VVUS.csv',
#  '../../05_src/data/prices_csv/stocks/AMRK.csv',
#  '../../05_src/data/prices_csv/stocks/GLP.csv',
#  '../../05_src/data/prices_csv/stocks/AHCO.csv',
#  '../../05_src/data/prices_csv/stocks/OXFD.csv',
#  '../../05_src/data/prices_csv/stocks/TANNL.csv',
#  '../../05_src/data/prices_csv/stocks/CTRC.csv',
#  '../../05_src/data/prices_csv/stocks/CHCT.csv',
#  '../../05_src/data/prices_csv/stocks/ADPT.csv',
#  '../../05_src/data/prices_csv/stocks/RDIB.csv',
#  '../../05_src/data/prices_csv/stocks/CREG.csv',
#  '../../05_src/data/prices_csv/stocks/SOHON.csv',
#  '../../05_src/data/prices_csv/stocks/NWPX.csv',
#  '../../05_src/data/prices_csv/stocks/XTLB.csv',
#  '../../05_src/data/prices_csv/stocks/AMTD.csv',
#  '../../05_src/data/prices_csv/stocks/DKS.csv',
#  '../../05_src/data/prices_csv/stocks/PFIS.csv',
#  '../../05_src/data/prices_csv/stocks/EHI.csv',
#  '../../05_src/data/prices_csv/stocks/SRT.csv',
#  '../../05_src/data/prices_csv/stocks/LTM.csv',
#  '../../05_src/data/prices_csv/stocks/JSD.csv',
#  '../../05_src/data/prices_csv/stocks/AHH.csv',
#  '../../05_src/data/prices_csv/stocks/BHC.csv',
#  '../../05_src/data/prices_csv/stocks/SEB.csv',
#  '../../05_src/data/prices_csv/stocks/JBGS.csv',
#  '../../05_src/data/prices_csv/stocks/XFLT.csv',
#  '../../05_src/data/prices_csv/stocks/OVBC.csv',
#  '../../05_src/data/prices_csv/stocks/EOG.csv',
#  '../../05_src/data/prices_csv/stocks/FDEF.csv',
#  '../../05_src/data/prices_csv/stocks/FDUS.csv',
#  '../../05_src/data/prices_csv/stocks/TCF.csv',
#  '../../05_src/data/prices_csv/stocks/AEZS.csv',
#  '../../05_src/data/prices_csv/stocks/SAND.csv',
#  '../../05_src/data/prices_csv/stocks/OBCI.csv',
#  '../../05_src/data/prices_csv/stocks/SABR.csv',
#  '../../05_src/data/prices_csv/stocks/BDXA.csv',
#  '../../05_src/data/prices_csv/stocks/MDIA.csv',
#  '../../05_src/data/prices_csv/stocks/MIDD.csv',
#  '../../05_src/data/prices_csv/stocks/NTN.csv',
#  '../../05_src/data/prices_csv/stocks/ANGO.csv',
#  '../../05_src/data/prices_csv/stocks/LAWS.csv',
#  '../../05_src/data/prices_csv/stocks/STC.csv',
#  '../../05_src/data/prices_csv/stocks/MVCD.csv',
#  '../../05_src/data/prices_csv/stocks/REYN.csv',
#  '../../05_src/data/prices_csv/stocks/CDK.csv',
#  '../../05_src/data/prices_csv/stocks/DSLV.csv',
#  '../../05_src/data/prices_csv/stocks/COP.csv',
#  '../../05_src/data/prices_csv/stocks/MOSY.csv',
#  '../../05_src/data/prices_csv/stocks/FARO.csv',
#  '../../05_src/data/prices_csv/stocks/TCMD.csv',
#  '../../05_src/data/prices_csv/stocks/DRAD.csv',
#  '../../05_src/data/prices_csv/stocks/VTA.csv',
#  '../../05_src/data/prices_csv/stocks/SRNE.csv',
#  '../../05_src/data/prices_csv/stocks/CAH.csv',
#  '../../05_src/data/prices_csv/stocks/RCON.csv',
#  '../../05_src/data/prices_csv/stocks/TRUP.csv',
#  '../../05_src/data/prices_csv/stocks/MSD.csv',
#  '../../05_src/data/prices_csv/stocks/TRMD.csv',
#  '../../05_src/data/prices_csv/stocks/MMLP.csv',
#  '../../05_src/data/prices_csv/stocks/AMOV.csv',
#  '../../05_src/data/prices_csv/stocks/FIXX.csv',
#  '../../05_src/data/prices_csv/stocks/AAON.csv',
#  '../../05_src/data/prices_csv/stocks/RARE.csv',
#  '../../05_src/data/prices_csv/stocks/IMKTA.csv',
#  '../../05_src/data/prices_csv/stocks/GL.csv',
#  '../../05_src/data/prices_csv/stocks/VERI.csv',
#  '../../05_src/data/prices_csv/stocks/DTJ.csv',
#  '../../05_src/data/prices_csv/stocks/AUPH.csv',
#  '../../05_src/data/prices_csv/stocks/SSTK.csv',
#  '../../05_src/data/prices_csv/stocks/CNCE.csv',
#  '../../05_src/data/prices_csv/stocks/BMA.csv',
#  '../../05_src/data/prices_csv/stocks/EPD.csv',
#  '../../05_src/data/prices_csv/stocks/JBLU.csv',
#  '../../05_src/data/prices_csv/stocks/LBY.csv',
#  '../../05_src/data/prices_csv/stocks/ACP.csv',
#  '../../05_src/data/prices_csv/stocks/EVLMC.csv',
#  '../../05_src/data/prices_csv/stocks/CNK.csv',
#  '../../05_src/data/prices_csv/stocks/ESNT.csv',
#  '../../05_src/data/prices_csv/stocks/BYD.csv',
#  '../../05_src/data/prices_csv/stocks/DYNT.csv',
#  '../../05_src/data/prices_csv/stocks/AJG.csv',
#  '../../05_src/data/prices_csv/stocks/PYPE.csv',
#  '../../05_src/data/prices_csv/stocks/COOP.csv',
#  '../../05_src/data/prices_csv/stocks/PAA.csv',
#  '../../05_src/data/prices_csv/stocks/OII.csv',
#  '../../05_src/data/prices_csv/stocks/PECK.csv',
#  '../../05_src/data/prices_csv/stocks/BLK.csv',
#  '../../05_src/data/prices_csv/stocks/EA.csv',
#  '../../05_src/data/prices_csv/stocks/MHK.csv',
#  '../../05_src/data/prices_csv/stocks/RNET.csv',
#  '../../05_src/data/prices_csv/stocks/DD.csv',
#  '../../05_src/data/prices_csv/stocks/SAQNU.csv',
#  '../../05_src/data/prices_csv/stocks/BKCC.csv',
#  '../../05_src/data/prices_csv/stocks/NWL.csv',
#  '../../05_src/data/prices_csv/stocks/OGCP.csv',
#  '../../05_src/data/prices_csv/stocks/NOG.csv',
#  '../../05_src/data/prices_csv/stocks/TEUM.csv',
#  '../../05_src/data/prices_csv/stocks/LKCO.csv',
#  '../../05_src/data/prices_csv/stocks/FRBK.csv',
#  '../../05_src/data/prices_csv/stocks/SHOO.csv',
#  '../../05_src/data/prices_csv/stocks/SRE.csv',
#  '../../05_src/data/prices_csv/stocks/CHRS.csv',
#  '../../05_src/data/prices_csv/stocks/HLI.csv',
#  '../../05_src/data/prices_csv/stocks/MDU.csv',
#  '../../05_src/data/prices_csv/stocks/INMD.csv',
#  '../../05_src/data/prices_csv/stocks/KBH.csv',
#  '../../05_src/data/prices_csv/stocks/MATX.csv',
#  '../../05_src/data/prices_csv/stocks/ICL.csv',
#  '../../05_src/data/prices_csv/stocks/WY.csv',
#  '../../05_src/data/prices_csv/stocks/JRS.csv',
#  '../../05_src/data/prices_csv/stocks/LOAC.csv',
#  '../../05_src/data/prices_csv/stocks/APY.csv',
#  '../../05_src/data/prices_csv/stocks/GLUU.csv',
#  '../../05_src/data/prices_csv/stocks/PDI.csv',
#  '../../05_src/data/prices_csv/stocks/ASB.csv',
#  '../../05_src/data/prices_csv/stocks/DLX.csv',
#  '../../05_src/data/prices_csv/stocks/HLX.csv',
#  '../../05_src/data/prices_csv/stocks/PNNTG.csv',
#  '../../05_src/data/prices_csv/stocks/WBT.csv',
#  '../../05_src/data/prices_csv/stocks/BWG.csv',
#  '../../05_src/data/prices_csv/stocks/IBKC.csv',
#  '../../05_src/data/prices_csv/stocks/PCYG.csv',
#  '../../05_src/data/prices_csv/stocks/ENO.csv',
#  '../../05_src/data/prices_csv/stocks/MAYS.csv',
#  '../../05_src/data/prices_csv/stocks/RDHL.csv',
#  '../../05_src/data/prices_csv/stocks/CSIQ.csv',
#  '../../05_src/data/prices_csv/stocks/HII.csv',
#  '../../05_src/data/prices_csv/stocks/CCRC.csv',
#  '../../05_src/data/prices_csv/stocks/MUE.csv',
#  '../../05_src/data/prices_csv/stocks/CWT.csv',
#  '../../05_src/data/prices_csv/stocks/INDB.csv',
#  '../../05_src/data/prices_csv/stocks/HJV.csv',
#  '../../05_src/data/prices_csv/stocks/PB.csv',
#  '../../05_src/data/prices_csv/stocks/TMUS.csv',
#  '../../05_src/data/prices_csv/stocks/HGH.csv',
#  '../../05_src/data/prices_csv/stocks/AGFS.csv',
#  '../../05_src/data/prices_csv/stocks/TTP.csv',
#  '../../05_src/data/prices_csv/stocks/ADP.csv',
#  '../../05_src/data/prices_csv/stocks/FSS.csv',
#  '../../05_src/data/prices_csv/stocks/VVNT.csv',
#  '../../05_src/data/prices_csv/stocks/THS.csv',
#  '../../05_src/data/prices_csv/stocks/MYF.csv',
#  '../../05_src/data/prices_csv/stocks/ZIONO.csv',
#  '../../05_src/data/prices_csv/stocks/HCKT.csv',
#  '../../05_src/data/prices_csv/stocks/AEP.csv',
#  '../../05_src/data/prices_csv/stocks/COLM.csv',
#  '../../05_src/data/prices_csv/stocks/BR.csv',
#  '../../05_src/data/prices_csv/stocks/SOLN.csv',
#  '../../05_src/data/prices_csv/stocks/EEX.csv',
#  '../../05_src/data/prices_csv/stocks/GGM.csv',
#  '../../05_src/data/prices_csv/stocks/RILYG.csv',
#  '../../05_src/data/prices_csv/stocks/NLTX.csv',
#  '../../05_src/data/prices_csv/stocks/HTBX.csv',
#  '../../05_src/data/prices_csv/stocks/VMC.csv',
#  '../../05_src/data/prices_csv/stocks/ADSW.csv',
#  '../../05_src/data/prices_csv/stocks/UPS.csv',
#  '../../05_src/data/prices_csv/stocks/PFFL.csv',
#  '../../05_src/data/prices_csv/stocks/VOC.csv',
#  '../../05_src/data/prices_csv/stocks/DT.csv',
#  '../../05_src/data/prices_csv/stocks/QTT.csv',
#  '../../05_src/data/prices_csv/stocks/YGYIP.csv',
#  '../../05_src/data/prices_csv/stocks/MCMJ.csv',
#  '../../05_src/data/prices_csv/stocks/SSL.csv',
#  '../../05_src/data/prices_csv/stocks/MMX.csv',
#  '../../05_src/data/prices_csv/stocks/NHC.csv',
#  '../../05_src/data/prices_csv/stocks/FPF.csv',
#  '../../05_src/data/prices_csv/stocks/GDL.csv',
#  '../../05_src/data/prices_csv/stocks/DOOO.csv',
#  '../../05_src/data/prices_csv/stocks/HCFT.csv',
#  '../../05_src/data/prices_csv/stocks/KEX.csv',
#  '../../05_src/data/prices_csv/stocks/TPTX.csv',
#  '../../05_src/data/prices_csv/stocks/AGR.csv',
#  '../../05_src/data/prices_csv/stocks/MYN.csv',
#  '../../05_src/data/prices_csv/stocks/CIIC.csv',
#  '../../05_src/data/prices_csv/stocks/RSF.csv',
#  '../../05_src/data/prices_csv/stocks/SXI.csv',
#  '../../05_src/data/prices_csv/stocks/STK.csv',
#  '../../05_src/data/prices_csv/stocks/LCUT.csv',
#  '../../05_src/data/prices_csv/stocks/BRKL.csv',
#  '../../05_src/data/prices_csv/stocks/WILC.csv',
#  '../../05_src/data/prices_csv/stocks/PKI.csv',
#  '../../05_src/data/prices_csv/stocks/AVA.csv',
#  '../../05_src/data/prices_csv/stocks/SONA.csv',
#  '../../05_src/data/prices_csv/stocks/RUN.csv',
#  '../../05_src/data/prices_csv/stocks/EFT.csv',
#  '../../05_src/data/prices_csv/stocks/FORR.csv',
#  '../../05_src/data/prices_csv/stocks/KNDI.csv',
#  '../../05_src/data/prices_csv/stocks/GTES.csv',
#  '../../05_src/data/prices_csv/stocks/NXTD.csv',
#  '../../05_src/data/prices_csv/stocks/TXMD.csv',
#  '../../05_src/data/prices_csv/stocks/EURN.csv',
#  '../../05_src/data/prices_csv/stocks/FBIO.csv',
#  '../../05_src/data/prices_csv/stocks/MLI.csv',
#  '../../05_src/data/prices_csv/stocks/SB.csv',
#  '../../05_src/data/prices_csv/stocks/RESN.csv',
#  '../../05_src/data/prices_csv/stocks/MHLD.csv',
#  '../../05_src/data/prices_csv/stocks/SAMG.csv',
#  '../../05_src/data/prices_csv/stocks/SRC.csv',
#  '../../05_src/data/prices_csv/stocks/ESBA.csv',
#  '../../05_src/data/prices_csv/stocks/MFINL.csv',
#  '../../05_src/data/prices_csv/stocks/MNK.csv',
#  '../../05_src/data/prices_csv/stocks/TWIN.csv',
#  '../../05_src/data/prices_csv/stocks/PNRG.csv',
#  '../../05_src/data/prices_csv/stocks/DMTK.csv',
#  '../../05_src/data/prices_csv/stocks/CTMX.csv',
#  '../../05_src/data/prices_csv/stocks/SNN.csv',
#  '../../05_src/data/prices_csv/stocks/LIN.csv',
#  '../../05_src/data/prices_csv/stocks/PROF.csv',
#  '../../05_src/data/prices_csv/stocks/SYNC.csv',
#  '../../05_src/data/prices_csv/stocks/MSEX.csv',
#  '../../05_src/data/prices_csv/stocks/NRK.csv',
#  '../../05_src/data/prices_csv/stocks/DRH.csv',
#  '../../05_src/data/prices_csv/stocks/FNKO.csv',
#  '../../05_src/data/prices_csv/stocks/MNP.csv',
#  '../../05_src/data/prices_csv/stocks/DPHC.csv',
#  '../../05_src/data/prices_csv/stocks/GHG.csv',
#  '../../05_src/data/prices_csv/stocks/GPAQ.csv',
#  '../../05_src/data/prices_csv/stocks/ALBO.csv',
#  '../../05_src/data/prices_csv/stocks/PNM.csv',
#  '../../05_src/data/prices_csv/stocks/IPDN.csv',
#  '../../05_src/data/prices_csv/stocks/TGP.csv',
#  '../../05_src/data/prices_csv/stocks/XGN.csv',
#  '../../05_src/data/prices_csv/stocks/MTH.csv',
#  '../../05_src/data/prices_csv/stocks/IFMK.csv',
#  '../../05_src/data/prices_csv/stocks/REI.csv',
#  '../../05_src/data/prices_csv/stocks/SCA.csv',
#  '../../05_src/data/prices_csv/stocks/ELS.csv',
#  '../../05_src/data/prices_csv/stocks/PBA.csv',
#  '../../05_src/data/prices_csv/stocks/MA.csv',
#  '../../05_src/data/prices_csv/stocks/OPNT.csv',
#  '../../05_src/data/prices_csv/stocks/AVGR.csv',
#  '../../05_src/data/prices_csv/stocks/CBB.csv',
#  '../../05_src/data/prices_csv/stocks/AMC.csv',
#  '../../05_src/data/prices_csv/stocks/EAF.csv',
#  '../../05_src/data/prices_csv/stocks/PINE.csv',
#  '../../05_src/data/prices_csv/stocks/ARCC.csv',
#  '../../05_src/data/prices_csv/stocks/OILX.csv',
#  '../../05_src/data/prices_csv/stocks/ATHE.csv',
#  '../../05_src/data/prices_csv/stocks/SPWR.csv',
#  '../../05_src/data/prices_csv/stocks/PCTI.csv',
#  '../../05_src/data/prices_csv/stocks/ARTNA.csv',
#  '../../05_src/data/prices_csv/stocks/BSVN.csv',
#  '../../05_src/data/prices_csv/stocks/SILC.csv',
#  '../../05_src/data/prices_csv/stocks/KIO.csv',
#  '../../05_src/data/prices_csv/stocks/BPY.csv',
#  '../../05_src/data/prices_csv/stocks/AMS.csv',
#  '../../05_src/data/prices_csv/stocks/MRVL.csv',
#  '../../05_src/data/prices_csv/stocks/SQBG.csv',
#  '../../05_src/data/prices_csv/stocks/UTHR.csv',
#  '../../05_src/data/prices_csv/stocks/BSBR.csv',
#  '../../05_src/data/prices_csv/stocks/ACRS.csv',
#  '../../05_src/data/prices_csv/stocks/OPCH.csv',
#  '../../05_src/data/prices_csv/stocks/AGBAU.csv',
#  '../../05_src/data/prices_csv/stocks/PRGO.csv',
#  '../../05_src/data/prices_csv/stocks/IFS.csv',
#  '../../05_src/data/prices_csv/stocks/KBAL.csv',
#  '../../05_src/data/prices_csv/stocks/NCV.csv',
#  '../../05_src/data/prices_csv/stocks/SMBK.csv',
#  '../../05_src/data/prices_csv/stocks/HOV.csv',
#  '../../05_src/data/prices_csv/stocks/HQI.csv',
#  '../../05_src/data/prices_csv/stocks/CFMS.csv',
#  '../../05_src/data/prices_csv/stocks/FREQ.csv',
#  '../../05_src/data/prices_csv/stocks/MZA.csv',
#  '../../05_src/data/prices_csv/stocks/GIS.csv',
#  '../../05_src/data/prices_csv/stocks/MSGN.csv',
#  '../../05_src/data/prices_csv/stocks/VRTU.csv',
#  '../../05_src/data/prices_csv/stocks/SCOR.csv',
#  '../../05_src/data/prices_csv/stocks/MBCN.csv',
#  '../../05_src/data/prices_csv/stocks/DENN.csv',
#  '../../05_src/data/prices_csv/stocks/BCEI.csv',
#  '../../05_src/data/prices_csv/stocks/PULM.csv',
#  '../../05_src/data/prices_csv/stocks/CXW.csv',
#  '../../05_src/data/prices_csv/stocks/MXL.csv',
#  '../../05_src/data/prices_csv/stocks/PTMN.csv',
#  '../../05_src/data/prices_csv/stocks/HYI.csv',
#  '../../05_src/data/prices_csv/stocks/CBRL.csv',
#  '../../05_src/data/prices_csv/stocks/CONE.csv',
#  '../../05_src/data/prices_csv/stocks/CMSC.csv',
#  '../../05_src/data/prices_csv/stocks/SC.csv',
#  '../../05_src/data/prices_csv/stocks/FCBC.csv',
#  '../../05_src/data/prices_csv/stocks/BJRI.csv',
#  '../../05_src/data/prices_csv/stocks/NBACU.csv',
#  '../../05_src/data/prices_csv/stocks/CNTY.csv',
#  '../../05_src/data/prices_csv/stocks/LACQ.csv',
#  '../../05_src/data/prices_csv/stocks/GOGO.csv',
#  '../../05_src/data/prices_csv/stocks/COHU.csv',
#  '../../05_src/data/prices_csv/stocks/CI.csv',
#  '../../05_src/data/prices_csv/stocks/EXLS.csv',
#  '../../05_src/data/prices_csv/stocks/SR.csv',
#  '../../05_src/data/prices_csv/stocks/TXG.csv',
#  '../../05_src/data/prices_csv/stocks/BFST.csv',
#  '../../05_src/data/prices_csv/stocks/INBK.csv',
#  '../../05_src/data/prices_csv/stocks/MFC.csv',
#  '../../05_src/data/prices_csv/stocks/STAA.csv',
#  '../../05_src/data/prices_csv/stocks/DXR.csv',
#  '../../05_src/data/prices_csv/stocks/AFGC.csv',
#  '../../05_src/data/prices_csv/stocks/TGI.csv',
#  '../../05_src/data/prices_csv/stocks/REG.csv',
#  '../../05_src/data/prices_csv/stocks/SDPI.csv',
#  '../../05_src/data/prices_csv/stocks/ING.csv',
#  '../../05_src/data/prices_csv/stocks/CETX.csv',
#  '../../05_src/data/prices_csv/stocks/UNF.csv',
#  '../../05_src/data/prices_csv/stocks/AAXN.csv',
#  '../../05_src/data/prices_csv/stocks/UMBF.csv',
#  '../../05_src/data/prices_csv/stocks/ROK.csv',
#  '../../05_src/data/prices_csv/stocks/CALA.csv',
#  '../../05_src/data/prices_csv/stocks/IDRA.csv',
#  '../../05_src/data/prices_csv/stocks/EMR.csv',
#  '../../05_src/data/prices_csv/stocks/NYMX.csv',
#  '../../05_src/data/prices_csv/stocks/AGRX.csv',
#  '../../05_src/data/prices_csv/stocks/BBSI.csv',
#  '../../05_src/data/prices_csv/stocks/FIT.csv',
#  '../../05_src/data/prices_csv/stocks/PGRE.csv',
#  '../../05_src/data/prices_csv/stocks/AGX.csv',
#  '../../05_src/data/prices_csv/stocks/SNPS.csv',
#  '../../05_src/data/prices_csv/stocks/ROLL.csv',
#  '../../05_src/data/prices_csv/stocks/IRS.csv',
#  '../../05_src/data/prices_csv/stocks/VCF.csv',
#  '../../05_src/data/prices_csv/stocks/CLPT.csv',
#  '../../05_src/data/prices_csv/stocks/CHI.csv',
#  '../../05_src/data/prices_csv/stocks/PFGC.csv',
#  '../../05_src/data/prices_csv/stocks/AESE.csv',
#  '../../05_src/data/prices_csv/stocks/SNGX.csv',
#  '../../05_src/data/prices_csv/stocks/ALG.csv',
#  '../../05_src/data/prices_csv/stocks/GENE.csv',
#  '../../05_src/data/prices_csv/stocks/MOR.csv',
#  '../../05_src/data/prices_csv/stocks/SMCI.csv',
#  '../../05_src/data/prices_csv/stocks/HALO.csv',
#  '../../05_src/data/prices_csv/stocks/EOD.csv',
#  '../../05_src/data/prices_csv/stocks/ICCC.csv',
#  '../../05_src/data/prices_csv/stocks/INFN.csv',
#  '../../05_src/data/prices_csv/stocks/UNFI.csv',
#  '../../05_src/data/prices_csv/stocks/ALDX.csv',
#  '../../05_src/data/prices_csv/stocks/EBIX.csv',
#  '../../05_src/data/prices_csv/stocks/GMRE.csv',
#  '../../05_src/data/prices_csv/stocks/COLL.csv',
#  '../../05_src/data/prices_csv/stocks/DLB.csv',
#  '../../05_src/data/prices_csv/stocks/CIFS.csv',
#  '../../05_src/data/prices_csv/stocks/LASR.csv',
#  '../../05_src/data/prices_csv/stocks/BPT.csv',
#  '../../05_src/data/prices_csv/stocks/EBTC.csv',
#  '../../05_src/data/prices_csv/stocks/CYCC.csv',
#  '../../05_src/data/prices_csv/stocks/MHNC.csv',
#  '../../05_src/data/prices_csv/stocks/SOJD.csv',
#  '../../05_src/data/prices_csv/stocks/JCTCF.csv',
#  '../../05_src/data/prices_csv/stocks/PAGS.csv',
#  '../../05_src/data/prices_csv/stocks/OPRT.csv',
#  '../../05_src/data/prices_csv/stocks/PCAR.csv',
#  '../../05_src/data/prices_csv/stocks/OVV.csv',
#  '../../05_src/data/prices_csv/stocks/HCACU.csv',
#  '../../05_src/data/prices_csv/stocks/ASMB.csv',
#  '../../05_src/data/prices_csv/stocks/PXS.csv',
#  '../../05_src/data/prices_csv/stocks/EVRG.csv',
#  '../../05_src/data/prices_csv/stocks/CASI.csv',
#  '../../05_src/data/prices_csv/stocks/GSK.csv',
#  '../../05_src/data/prices_csv/stocks/CAE.csv',
#  '../../05_src/data/prices_csv/stocks/AVRO.csv',
#  '../../05_src/data/prices_csv/stocks/GLBZ.csv',
#  '../../05_src/data/prices_csv/stocks/AGD.csv',
#  '../../05_src/data/prices_csv/stocks/RFP.csv',
#  '../../05_src/data/prices_csv/stocks/CTHR.csv',
#  '../../05_src/data/prices_csv/stocks/FIVE.csv',
#  '../../05_src/data/prices_csv/stocks/HOG.csv',
#  '../../05_src/data/prices_csv/stocks/HTHT.csv',
#  '../../05_src/data/prices_csv/stocks/VXRT.csv',
#  '../../05_src/data/prices_csv/stocks/BHK.csv',
#  '../../05_src/data/prices_csv/stocks/EVY.csv',
#  '../../05_src/data/prices_csv/stocks/GILD.csv',
#  '../../05_src/data/prices_csv/stocks/CENTA.csv',
#  '../../05_src/data/prices_csv/stocks/NGHCP.csv',
#  '../../05_src/data/prices_csv/stocks/TDS.csv',
#  '../../05_src/data/prices_csv/stocks/GRAF.csv',
#  '../../05_src/data/prices_csv/stocks/CSPI.csv',
#  '../../05_src/data/prices_csv/stocks/HRTX.csv',
#  '../../05_src/data/prices_csv/stocks/KELYA.csv',
#  '../../05_src/data/prices_csv/stocks/ASRVP.csv',
#  '../../05_src/data/prices_csv/stocks/SCWX.csv',
#  '../../05_src/data/prices_csv/stocks/GROW.csv',
#  '../../05_src/data/prices_csv/stocks/BKEPP.csv',
#  '../../05_src/data/prices_csv/stocks/FIEE.csv',
#  '../../05_src/data/prices_csv/stocks/NNDM.csv',
#  '../../05_src/data/prices_csv/stocks/RPLA.csv',
#  '../../05_src/data/prices_csv/stocks/PKG.csv',
#  '../../05_src/data/prices_csv/stocks/DLHC.csv',
#  '../../05_src/data/prices_csv/stocks/SA.csv',
#  '../../05_src/data/prices_csv/stocks/MBINP.csv',
#  '../../05_src/data/prices_csv/stocks/GEL.csv',
#  '../../05_src/data/prices_csv/stocks/DAN.csv',
#  '../../05_src/data/prices_csv/stocks/KWR.csv',
#  '../../05_src/data/prices_csv/stocks/SJIJ.csv',
#  '../../05_src/data/prices_csv/stocks/ESRT.csv',
#  '../../05_src/data/prices_csv/stocks/GSUM.csv',
#  '../../05_src/data/prices_csv/stocks/PETS.csv',
#  '../../05_src/data/prices_csv/stocks/NTCO.csv',
#  '../../05_src/data/prices_csv/stocks/IBKR.csv',
#  '../../05_src/data/prices_csv/stocks/SAR.csv',
#  '../../05_src/data/prices_csv/stocks/VAC.csv',
#  '../../05_src/data/prices_csv/stocks/CEVA.csv',
#  '../../05_src/data/prices_csv/stocks/MMC.csv',
#  '../../05_src/data/prices_csv/stocks/IX.csv',
#  '../../05_src/data/prices_csv/stocks/RMCF.csv',
#  '../../05_src/data/prices_csv/stocks/HYAC.csv',
#  '../../05_src/data/prices_csv/stocks/QSR.csv',
#  '../../05_src/data/prices_csv/stocks/ITT.csv',
#  '../../05_src/data/prices_csv/stocks/GNRC.csv',
#  '../../05_src/data/prices_csv/stocks/PSB.csv',
#  '../../05_src/data/prices_csv/stocks/RAIL.csv',
#  '../../05_src/data/prices_csv/stocks/HAYN.csv',
#  '../../05_src/data/prices_csv/stocks/MUC.csv',
#  '../../05_src/data/prices_csv/stocks/BUD.csv',
#  '../../05_src/data/prices_csv/stocks/CINF.csv',
#  '../../05_src/data/prices_csv/stocks/DRE.csv',
#  '../../05_src/data/prices_csv/stocks/NSYS.csv',
#  '../../05_src/data/prices_csv/stocks/APTS.csv',
#  '../../05_src/data/prices_csv/stocks/GGAL.csv',
#  '../../05_src/data/prices_csv/stocks/LIVX.csv',
#  '../../05_src/data/prices_csv/stocks/SIM.csv',
#  '../../05_src/data/prices_csv/stocks/GRN.csv',
#  '../../05_src/data/prices_csv/stocks/AR.csv',
#  '../../05_src/data/prices_csv/stocks/MCFT.csv',
#  '../../05_src/data/prices_csv/stocks/ISD.csv',
#  '../../05_src/data/prices_csv/stocks/CATC.csv',
#  '../../05_src/data/prices_csv/stocks/RUSHA.csv',
#  '../../05_src/data/prices_csv/stocks/CYCN.csv',
#  '../../05_src/data/prices_csv/stocks/NKE.csv',
#  '../../05_src/data/prices_csv/stocks/CBMB.csv',
#  '../../05_src/data/prices_csv/stocks/CVS.csv',
#  '../../05_src/data/prices_csv/stocks/OBAS.csv',
#  '../../05_src/data/prices_csv/stocks/TLC.csv',
#  '../../05_src/data/prices_csv/stocks/BIT.csv',
#  '../../05_src/data/prices_csv/stocks/WK.csv',
#  '../../05_src/data/prices_csv/stocks/CPST.csv',
#  '../../05_src/data/prices_csv/stocks/CHEK.csv',
#  '../../05_src/data/prices_csv/stocks/MGIC.csv',
#  '../../05_src/data/prices_csv/stocks/HPE.csv',
#  '../../05_src/data/prices_csv/stocks/AHPI.csv',
#  '../../05_src/data/prices_csv/stocks/PMF.csv',
#  '../../05_src/data/prices_csv/stocks/ZLAB.csv',
#  '../../05_src/data/prices_csv/stocks/LMRK.csv',
#  '../../05_src/data/prices_csv/stocks/ADUS.csv',
#  '../../05_src/data/prices_csv/stocks/CUTR.csv',
#  '../../05_src/data/prices_csv/stocks/LHX.csv',
#  '../../05_src/data/prices_csv/stocks/CNDT.csv',
#  '../../05_src/data/prices_csv/stocks/B.csv',
#  '../../05_src/data/prices_csv/stocks/DWSN.csv',
#  '../../05_src/data/prices_csv/stocks/ZTO.csv',
#  '../../05_src/data/prices_csv/stocks/MYO.csv',
#  '../../05_src/data/prices_csv/stocks/LN.csv',
#  '../../05_src/data/prices_csv/stocks/PODD.csv',
#  '../../05_src/data/prices_csv/stocks/NGHCO.csv',
#  '../../05_src/data/prices_csv/stocks/VSTO.csv',
#  '../../05_src/data/prices_csv/stocks/FBHS.csv',
#  '../../05_src/data/prices_csv/stocks/EDF.csv',
#  '../../05_src/data/prices_csv/stocks/SGB.csv',
#  '../../05_src/data/prices_csv/stocks/INSP.csv',
#  '../../05_src/data/prices_csv/stocks/HCCO.csv',
#  '../../05_src/data/prices_csv/stocks/THM.csv',
#  '../../05_src/data/prices_csv/stocks/ELMD.csv',
#  '../../05_src/data/prices_csv/stocks/LTRX.csv',
#  '../../05_src/data/prices_csv/stocks/GJH.csv',
#  '../../05_src/data/prices_csv/stocks/JTD.csv',
#  '../../05_src/data/prices_csv/stocks/SCVL.csv',
#  '../../05_src/data/prices_csv/stocks/STZ.csv',
#  '../../05_src/data/prices_csv/stocks/BCOV.csv',
#  '../../05_src/data/prices_csv/stocks/LJPC.csv',
#  '../../05_src/data/prices_csv/stocks/DOGZ.csv',
#  '../../05_src/data/prices_csv/stocks/ECHO.csv',
#  '../../05_src/data/prices_csv/stocks/CARR#.csv',
#  '../../05_src/data/prices_csv/stocks/LQDT.csv',
#  '../../05_src/data/prices_csv/stocks/DXYN.csv',
#  '../../05_src/data/prices_csv/stocks/RMBL.csv',
#  '../../05_src/data/prices_csv/stocks/CLLS.csv',
#  '../../05_src/data/prices_csv/stocks/NEX.csv',
#  '../../05_src/data/prices_csv/stocks/BEDU.csv',
#  '../../05_src/data/prices_csv/stocks/AREC.csv',
#  '../../05_src/data/prices_csv/stocks/VIRT.csv',
#  '../../05_src/data/prices_csv/stocks/AZUL.csv',
#  '../../05_src/data/prices_csv/stocks/PLG.csv',
#  '../../05_src/data/prices_csv/stocks/CMCM.csv',
#  '../../05_src/data/prices_csv/stocks/ABM.csv',
#  '../../05_src/data/prices_csv/stocks/PRTA.csv',
#  '../../05_src/data/prices_csv/stocks/AMRS.csv',
#  '../../05_src/data/prices_csv/stocks/SNMP.csv',
#  '../../05_src/data/prices_csv/stocks/SUI.csv',
#  '../../05_src/data/prices_csv/stocks/NVMI.csv',
#  '../../05_src/data/prices_csv/stocks/FENC.csv',
#  '../../05_src/data/prices_csv/stocks/SIEN.csv',
#  '../../05_src/data/prices_csv/stocks/NMZ.csv',
#  '../../05_src/data/prices_csv/stocks/NXRT.csv',
#  '../../05_src/data/prices_csv/stocks/YIN.csv',
#  '../../05_src/data/prices_csv/stocks/PCRX.csv',
#  '../../05_src/data/prices_csv/stocks/SDGR.csv',
#  '../../05_src/data/prices_csv/stocks/EFOI.csv',
#  '../../05_src/data/prices_csv/stocks/MNSB.csv',
#  '../../05_src/data/prices_csv/stocks/MREO.csv',
#  '../../05_src/data/prices_csv/stocks/RILY.csv',
#  '../../05_src/data/prices_csv/stocks/WFC.csv',
#  '../../05_src/data/prices_csv/stocks/PYN.csv',
#  '../../05_src/data/prices_csv/stocks/NR.csv',
#  '../../05_src/data/prices_csv/stocks/ET.csv',
#  '../../05_src/data/prices_csv/stocks/BGSF.csv',
#  '../../05_src/data/prices_csv/stocks/BPYPO.csv',
#  '../../05_src/data/prices_csv/stocks/PCH.csv',
#  '../../05_src/data/prices_csv/stocks/WAB.csv',
#  '../../05_src/data/prices_csv/stocks/SPLP.csv',
#  '../../05_src/data/prices_csv/stocks/MOGO.csv',
#  '../../05_src/data/prices_csv/stocks/SLM.csv',
#  '../../05_src/data/prices_csv/stocks/CLCT.csv',
#  '../../05_src/data/prices_csv/stocks/CLS.csv',
#  '../../05_src/data/prices_csv/stocks/MWK.csv',
#  '../../05_src/data/prices_csv/stocks/CEO.csv',
#  '../../05_src/data/prices_csv/stocks/GATX.csv',
#  '../../05_src/data/prices_csv/stocks/RLI.csv',
#  '../../05_src/data/prices_csv/stocks/PCTY.csv',
#  '../../05_src/data/prices_csv/stocks/GGG.csv',
#  '../../05_src/data/prices_csv/stocks/NSA.csv',
#  '../../05_src/data/prices_csv/stocks/CLR.csv',
#  '../../05_src/data/prices_csv/stocks/ETN.csv',
#  '../../05_src/data/prices_csv/stocks/WF.csv',
#  '../../05_src/data/prices_csv/stocks/LOCO.csv',
#  '../../05_src/data/prices_csv/stocks/TVC.csv',
#  '../../05_src/data/prices_csv/stocks/TOTA.csv',
#  '../../05_src/data/prices_csv/stocks/DGX.csv',
#  '../../05_src/data/prices_csv/stocks/HMLP.csv',
#  '../../05_src/data/prices_csv/stocks/CTRA.csv',
#  '../../05_src/data/prices_csv/stocks/WHLRP.csv',
#  '../../05_src/data/prices_csv/stocks/THFF.csv',
#  '../../05_src/data/prices_csv/stocks/MMM.csv',
#  '../../05_src/data/prices_csv/stocks/EGAN.csv',
#  '../../05_src/data/prices_csv/stocks/JVA.csv',
#  '../../05_src/data/prices_csv/stocks/CHCO.csv',
#  '../../05_src/data/prices_csv/stocks/UGI.csv',
#  '../../05_src/data/prices_csv/stocks/SIGA.csv',
#  '../../05_src/data/prices_csv/stocks/DIS.csv',
#  '../../05_src/data/prices_csv/stocks/CRBP.csv',
#  ...]

# %%
import random
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))


random.seed(42)
stock_files = random.sample(stock_files, 1)

dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    # print(dt)
    dt_list.append(dt)
    #print(dt_list)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
print(stock_prices)
# Out:
# 2025-06-11 00:29:53,227, 342909591.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IAA.csv
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2008-05-22   1.860000   1.950000   1.860000   1.950000   1.950000
# 1    2008-05-23   1.950000   2.040000   1.950000   2.040000   2.040000
# 2    2008-05-27   2.140000   2.230000   2.140000   2.230000   2.230000
# 3    2008-05-28   2.230000   2.340000   2.230000   2.340000   2.340000
# 4    2008-05-30   2.340000   2.340000   2.230000   2.230000   2.230000
# ...         ...        ...        ...        ...        ...        ...
# 2581 2020-03-26  30.889999  33.660000  29.280001  32.730000  32.730000
# 2582 2020-03-27  32.459999  32.779999  29.920000  32.310001  32.310001
# 2583 2020-03-30  32.570000  33.450001  31.530001  31.930000  31.930000
# 2584 2020-03-31  32.119999  32.630001  29.139999  29.959999  29.959999
# 2585 2020-04-01  29.240000  30.020000  27.219999  27.590000  27.590000
#
#           Volume   source ticker
# 0       66833800  IAA.csv    IAA
# 1     1138641200  IAA.csv    IAA
# 2     1220142800  IAA.csv    IAA
# 3     1163506000  IAA.csv    IAA
# 4      299143500  IAA.csv    IAA
# ...          ...      ...    ...
# 2581     1427200  IAA.csv    IAA
# 2582     1071500  IAA.csv    IAA
# 2583     1717300  IAA.csv    IAA
# 2584     1605000  IAA.csv    IAA
# 2585     1221500  IAA.csv    IAA
#
# [2586 rows x 9 columns]

# %%
import random

# This script reads stock price data from CSV files, processes it, and combines it into a single DataFrame.
# It randomly selects 60 stock files from a specified directory and reads their contents into a DataFrame.
# The DataFrame includes a 'source' column indicating the file name and a 'ticker' column derived from the file name.
# It also converts the 'Date' column to datetime format for easier manipulation and analysis.
# Ensure the SRC_DIR environment variable is set to the correct path
# before running this script.

# what does this glob do? can you be more descriptive?
# The glob function is used to find all CSV files in the specified directory that match the pattern.
# It retrieves all files with a .csv extension in the 'data/prices_csv/stocks' directory.
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))


random.seed(42)
stock_files = random.sample(stock_files, 60)

dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    # Read each CSV file into a DataFrame, adding 'source' and 'ticker' columns.
    # The 'source' column contains the file name, and the 'ticker' column is derived from the file name.
    # The 'Date' column is converted to datetime format for easier manipulation.
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    # Append the DataFrame to a list for later concatenation. 
    dt_list.append(dt)
# Concatenate all DataFrames in the list into a single DataFrame.
# This DataFrame will contain all stock prices from the selected files, with additional metadata.
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)

# Instead of concatenating each dataframe, we add them to a list and then concatenate them all at once.
# Conactenating each dataframe one by one can be inefficient, especially with a large number of files as 
# it creates multiple intermediate DataFrames in memory. You would need to rebuild the entire DataFrame
# each time you concatenate a new DataFrame, which can be slow and memory-intensive.
# Out:
# 2025-06-11 00:29:17,514, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IAA.csv
# 2025-06-11 00:29:17,613, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LN.csv
# 2025-06-11 00:29:17,726, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BTU.csv
# 2025-06-11 00:29:17,883, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WMGI.csv
# 2025-06-11 00:29:18,299, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CFXA.csv
# 2025-06-11 00:29:18,394, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ICCH.csv
# 2025-06-11 00:29:18,488, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CNX.csv
# 2025-06-11 00:29:18,832, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KELYA.csv
# 2025-06-11 00:29:19,287, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MLPO.csv
# 2025-06-11 00:29:19,415, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GFY.csv
# 2025-06-11 00:29:19,646, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SQBG.csv
# 2025-06-11 00:29:19,903, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TBLT.csv
# 2025-06-11 00:29:20,032, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATMP.csv
# 2025-06-11 00:29:20,212, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CO.csv
# 2025-06-11 00:29:20,397, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PPIH.csv
# 2025-06-11 00:29:20,815, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AAXN.csv
# 2025-06-11 00:29:21,174, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BBX.csv
# 2025-06-11 00:29:21,504, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GFLU.csv
# 2025-06-11 00:29:21,617, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PMM.csv
# 2025-06-11 00:29:22,154, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IMTE.csv
# 2025-06-11 00:29:22,293, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WTREP.csv
# 2025-06-11 00:29:22,377, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/POAI.csv
# 2025-06-11 00:29:22,532, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LINX.csv
# 2025-06-11 00:29:22,662, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SGMO.csv
# 2025-06-11 00:29:22,904, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FNGU.csv
# 2025-06-11 00:29:22,984, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KO.csv
# 2025-06-11 00:29:23,621, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CARE.csv
# 2025-06-11 00:29:23,900, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/XRF.csv
# 2025-06-11 00:29:24,021, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FRAF.csv
# 2025-06-11 00:29:24,341, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NSC.csv
# 2025-06-11 00:29:24,842, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/YJ.csv
# 2025-06-11 00:29:24,952, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NZF.csv
# 2025-06-11 00:29:25,211, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ERII.csv
# 2025-06-11 00:29:25,412, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GSV.csv
# 2025-06-11 00:29:25,551, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NCR.csv
# 2025-06-11 00:29:25,828, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IPHA.csv
# 2025-06-11 00:29:25,918, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NVRO.csv
# 2025-06-11 00:29:26,031, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MEET.csv
# 2025-06-11 00:29:26,214, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AVB.csv
# 2025-06-11 00:29:26,717, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IESC.csv
# 2025-06-11 00:29:27,010, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AGIO.csv
# 2025-06-11 00:29:27,203, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CSPI.csv
# 2025-06-11 00:29:27,455, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DXR.csv
# 2025-06-11 00:29:27,725, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WHG.csv
# 2025-06-11 00:29:27,906, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HALO.csv
# 2025-06-11 00:29:28,084, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ERF.csv
# 2025-06-11 00:29:28,350, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NAT.csv
# 2025-06-11 00:29:28,652, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATRA.csv
# 2025-06-11 00:29:28,765, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WIA.csv
# 2025-06-11 00:29:28,976, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AGM-A.csv
# 2025-06-11 00:29:29,156, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JOF.csv
# 2025-06-11 00:29:29,491, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EAE.csv
# 2025-06-11 00:29:29,871, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NTGR.csv
# 2025-06-11 00:29:30,216, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CSCO.csv
# 2025-06-11 00:29:30,718, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PKI.csv
# 2025-06-11 00:29:31,166, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SBH.csv
# 2025-06-11 00:29:31,289, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AEL.csv
# 2025-06-11 00:29:31,509, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GXGX.csv
# 2025-06-11 00:29:31,581, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FT.csv
# 2025-06-11 00:29:31,828, 4017565964.py, 21, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CUI.csv

# %%
stock_prices
# Out:
#              Date  Open   High   Low  Close  Adj Close        Volume   source  \
# 0      2008-05-22  1.86  1.950  1.86  1.950      1.950  6.683380e+07  IAA.csv
# 1      2008-05-23  1.95  2.040  1.95  2.040      2.040  1.138641e+09  IAA.csv
# 2      2008-05-27  2.14  2.230  2.14  2.230      2.230  1.220143e+09  IAA.csv
# 3      2008-05-28  2.23  2.340  2.23  2.340      2.340  1.163506e+09  IAA.csv
# 4      2008-05-30  2.34  2.340  2.23  2.230      2.230  2.991435e+08  IAA.csv
# ...           ...   ...    ...   ...    ...        ...           ...      ...
# 245470 2020-03-26  0.70  0.892  0.68  0.848      0.848  5.990000e+04  CUI.csv
# 245471 2020-03-27  0.85  0.899  0.71  0.860      0.860  8.390000e+04  CUI.csv
# 245472 2020-03-30  0.96  0.960  0.88  0.930      0.930  7.620000e+04  CUI.csv
# 245473 2020-03-31  0.94  0.980  0.82  0.891      0.891  1.385000e+05  CUI.csv
# 245474 2020-04-01  0.85  0.860  0.80  0.850      0.850  3.920000e+04  CUI.csv
#
#        ticker
# 0         IAA
# 1         IAA
# 2         IAA
# 3         IAA
# 4         IAA
# ...       ...
# 245470    CUI
# 245471    CUI
# 245472    CUI
# 245473    CUI
# 245474    CUI
#
# [245475 rows x 9 columns]

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245475 entries, 0 to 245474
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       245475 non-null  datetime64[ns]
#  1   Open       245452 non-null  float64
#  2   High       245452 non-null  float64
#  3   Low        245452 non-null  float64
#  4   Close      245452 non-null  float64
#  5   Adj Close  245452 non-null  float64
#  6   Volume     245452 non-null  float64
#  7   source     245475 non-null  object
#  8   ticker     245475 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.9+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['IAA',
#  'LN',
#  'BTU',
#  'WMGI',
#  'CFXA',
#  'ICCH',
#  'CNX',
#  'KELYA',
#  'MLPO',
#  'GFY',
#  'SQBG',
#  'TBLT',
#  'ATMP',
#  'CO',
#  'PPIH',
#  'AAXN',
#  'BBX',
#  'GFLU',
#  'PMM',
#  'IMTE',
#  'WTREP',
#  'POAI',
#  'LINX',
#  'SGMO',
#  'FNGU',
#  'KO',
#  'CARE',
#  'XRF',
#  'FRAF',
#  'NSC',
#  'YJ',
#  'NZF',
#  'ERII',
#  'GSV',
#  'NCR',
#  'IPHA',
#  'NVRO',
#  'MEET',
#  'AVB',
#  'IESC',
#  'AGIO',
#  'CSPI',
#  'DXR',
#  'WHG',
#  'HALO',
#  'ERF',
#  'NAT',
#  'ATRA',
#  'WIA',
#  'AGM-A',
#  'JOF',
#  'EAE',
#  'NTGR',
#  'CSCO',
#  'PKI',
#  'SBH',
#  'AEL',
#  'GXGX',
#  'FT',
#  'CUI']

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
path = '.'
with os.scandir(path) as entries:
    for entry in entries:
       print(entry)
# Out:
# <DirEntry '05_hyperparams.ipynb'>
# <DirEntry 'images'>
# <DirEntry '.env'>
# <DirEntry '03a_sampling.ipynb'>
# <DirEntry '07_distribution_shifts.ipynb'>
# <DirEntry '02_data_engineering.ipynb'>
# <DirEntry '06_explainability.ipynb'>
# <DirEntry '01_setup.ipynb'>
# <DirEntry '04_transforms.ipynb'>
# <DirEntry '03b_pipeline.ipynb'>

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            print(entry)
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
print(csv_dir)
shutil.rmtree(csv_dir, ignore_errors=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")
os.makedirs(csv_dir, exist_ok=True)
# Out:
# ../../05_src/data/temp/csv

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-06-11 00:29:58,517, 473192941.py, 5, INFO, Writing data ((2586, 9)) to csv took 0.04229283332824707 seconds.
# 2025-06-11 00:29:58,519, 473192941.py, 6, INFO, CSV file size 0.141147 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask
print(dask.__version__)

import sys
print(sys.version)
# Out:
# 2024.2.1
# 3.9.21 (main, Dec 11 2024, 16:24:11)
# [GCC 11.2.0]

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 import dask.dataframe as dd
#       3 parquet_dir = os.path.join(temp, "parquet")
#       4 shutil.rmtree(parquet_dir, ignore_errors=True)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/__init__.py:100
#      98 import dask.dataframe._pyarrow_compat
#      99 from dask.base import compute
# --> 100 from dask.dataframe import backends, dispatch, rolling
#     101 from dask.dataframe.core import (
#     102     DataFrame,
#     103     Index,
#    (...)
#     109     to_timedelta,
#     110 )
#     111 from dask.dataframe.groupby import Aggregation
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/backends.py:10
#       7 import pandas as pd
#       8 from pandas.api.types import is_scalar, union_categoricals
# ---> 10 from dask.array.core import Array
#      11 from dask.array.dispatch import percentile_lookup
#      12 from dask.array.percentile import _percentile
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/array/__init__.py:4
#       1 from __future__ import annotations
#       3 try:
# ----> 4     from dask.array import backends, fft, lib, linalg, ma, overlap, random
#       5     from dask.array.blockwise import atop, blockwise
#       6     from dask.array.chunk_types import register_chunk_type
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/array/backends.py:8
#       5 import numpy as np
#       7 from dask.array import chunk
# ----> 8 from dask.array.core import Array
#       9 from dask.array.dispatch import (
#      10     concatenate_lookup,
#      11     divide_lookup,
#    (...)
#      19     to_numpy_dispatch,
#      20 )
#      21 from dask.array.numpy_compat import divide as np_divide
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/array/core.py:63
#      61 from dask.highlevelgraph import HighLevelGraph, MaterializedLayer
#      62 from dask.layers import ArraySliceDep, reshapelist
# ---> 63 from dask.sizeof import sizeof
#      64 from dask.typing import Graph, Key, NestedKeys
#      65 from dask.utils import (
#      66     IndexCallable,
#      67     SerializableLock,
#    (...)
#      84     typename,
#      85 )
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/sizeof.py:273
#     267         except Exception:
#     268             logger.exception(
#     269                 f"Failed to register sizeof entry point {entry_point.name}"
#     270             )
# --> 273 _register_entry_point_plugins()
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/sizeof.py:263, in _register_entry_point_plugins()
#     261 def _register_entry_point_plugins():
#     262     """Register sizeof implementations exposed by the entry_point mechanism."""
# --> 263     for entry_point in importlib_metadata.entry_points(group="dask.sizeof"):
#     264         registrar = entry_point.load()
#     265         try:
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/importlib_metadata/__init__.py:1051, in entry_points(**params)
#    1040 """Return EntryPoint objects for all installed packages.
#    1041
#    1042 Pass selection parameters (group or name) to filter the
#    (...)
#    1046 :return: EntryPoints for all installed packages.
#    1047 """
#    1048 eps = itertools.chain.from_iterable(
#    1049     dist.entry_points for dist in _unique(distributions())
#    1050 )
# -> 1051 return EntryPoints(eps).select(**params)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/importlib_metadata/__init__.py:1048, in <genexpr>(.0)
#    1039 def entry_points(**params) -> EntryPoints:
#    1040     """Return EntryPoint objects for all installed packages.
#    1041
#    1042     Pass selection parameters (group or name) to filter the
#    (...)
#    1046     :return: EntryPoints for all installed packages.
#    1047     """
# -> 1048     eps = itertools.chain.from_iterable(
#    1049         dist.entry_points for dist in _unique(distributions())
#    1050     )
#    1051     return EntryPoints(eps).select(**params)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/importlib_metadata/_itertools.py:16, in unique_everseen(iterable, key)
#      14         yield element
#      15 else:
# ---> 16     for element in iterable:
#      17         k = key(element)
#      18         if k not in seen:
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/importlib_metadata/__init__.py:931, in <genexpr>(.0)
#     928 """Find metadata directories in paths heuristically."""
#     929 prepared = Prepared(name)
#     930 return itertools.chain.from_iterable(
# --> 931     path.search(prepared) for path in map(FastPath, paths)
#     932 )
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/importlib_metadata/__init__.py:790, in FastPath.search(self, name)
#     789 def search(self, name):
# --> 790     return self.lookup(self.mtime).search(name)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/importlib_metadata/__init__.py:795, in FastPath.mtime(self)
#     792 @property
#     793 def mtime(self):
#     794     with suppress(OSError):
# --> 795         return os.stat(self.root).st_mtime
#     796     self.lookup.cache_clear()
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))
#       3 start = time.time()
#       4 px_dd.to_parquet(parquet_dir, engine = "pyarrow")
#
# NameError: name 'dd' is not defined

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 5
#       3 ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
#       4 for yr in ticker_dt['Year'].unique():
# ----> 5     yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
#       6     yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
#       7     os.makedirs(os.path.dirname(yr_path), exist_ok=True)
#
# NameError: name 'dd' is not defined

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
